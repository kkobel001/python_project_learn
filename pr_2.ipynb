# %% [markdown]
# <a href="https://colab.research.google.com/github/kkobel001/python_project_learn/blob/main/pr_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("numbers.txt", "w", encoding="utf-8") as file:
  file.write('555\n')
  file.write('23\n')
  file.write('1\n')
  file.write('448595959595\n')

  filename="numbers.txt"
  sum=0
try:
  with open(filename, "r", encoding="utf-8") as file:
    print(f"Open file {filename}")
    lines=file.readlines()
    print(lines)

    for line in lines:
      try:
        value=int(line.strip())
        print(value)
        sum += value
      except ValueError:
        print(f"Nieproawdidłowa linia {line}")

except FileNotFoundError:
  print("nie ma takiego pliku")
else:
  print(f"sum of values {sum}")
finally:
  print("jest dobrze")
# Out:
# Open file numbers.txt
# ['555\n', '23\n', '1\n', '448595959595\n']
# 555
# 23
# 1
# 448595959595
# sum of values 448595960174
# jest dobrze
