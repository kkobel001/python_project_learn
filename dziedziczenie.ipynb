# %% [markdown]
# <a href="https://colab.research.google.com/github/kkobel001/python_project_learn/blob/main/dziedziczenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
int_variable=5

print(type(int_variable))

text='cos tam'

print(type(text))

print(text.upper())

nums=[1,2,3]
print(type(nums))

dict_example={}
print(type(dict_example))
print(dict_example.keys())


class Animal:
  def __init__(self,name):
    self.name=name

  def speak(self):
    return "..."

  def __str__(self):
    return f"{self.name} says : {self.speak()}"

class Dog(Animal):
  def speak(self):
    return  "Wooo!"


class Cat(Animal):
  def speak(self):
    return  "Miau!"

class Cow(Animal):
  def speak(self):
    return  "Muu!"

dog=Dog("Burek")
cat=Cat("Mruczek")
cow=Cow("Mucka")

print(dog)
print(cat)
print(cow)

for animal in [dog,cat,cow]:
  print(animal.speak())
# Out:
# <class 'int'>
# <class 'str'>
# COS TAM
# <class 'list'>
# <class 'dict'>
# dict_keys([])
# Burek says : Wooo!
# Mruczek says : Miau!
# Mucka says : Muu!
# Wooo!
# Miau!
# Muu!
