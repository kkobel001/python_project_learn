# %% [markdown]
# <a href="https://colab.research.google.com/github/kkobel001/python_project_learn/blob/main/Error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int(input("enter number : "))
  result=10/num
  print(result)

except ZeroDivisionError:
  print("mamy error")
except ValueError:
  print("to nie int")
except:
  print("default except")
finally:
  print("finally")
print("end of program")
# Out:
# enter number : h
# to nie int
# finally
# end of program

# %%
num = int(input("enter number : "))
if num<=0:
  print("negative value")
  raise ValueError("Wartosc musi byc wieksza niz zero")
result=10/num
# Out:
# enter number : -2
# negative value
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2695625606.py in <cell line: 0>()
#       2 if num<=0:
#       3   print("negative value")
# ----> 4   raise ValueError("Wartosc musi byc wieksza niz zero")
#       5 result=10/num
#
# ValueError: Wartosc musi byc wieksza niz zero

# %%
file = open("hello.txt","w", encoding="utf-8")
file.write("hello file\n")
file.write("534")
file.close()

file = open("hello.txt", "r", encoding="utf-8")
content=file.read()
file.close()

print(content)
# Out:
# hel

# %%
with open("hello.txt", "w", encoding="utf-8") as file:
  file.write('Hello again\n')
  file.write('cos tam\n')
  file.write('Kasia you can do it\n')
  file.write('Hhfhfhn\n')

with open("hello.txt", "r", encoding="utf-8") as file:
  content=file.read()
print(content.splitlines())

# print(content.splitlines())
# print(content.split('i'))


with open("hello.txt", "r", encoding="utf-8") as file:
  content=file.readlines()
  print(content)
# print(content.splitlines())
# Out:
# ['Hello again', 'cos tam', 'Kasia you can do it', 'Hhfhfhn']
# ['Hello again\n', 'cos tam\n', 'Kasia you can do it\n', 'Hhfhfhn\n']
