# %% [markdown]
# <a href="https://colab.research.google.com/github/kkobel001/python_project_learn/blob/main/funkcje.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def easy_print():
  print("Hello")

#argument pozycyjny
def print_numbers(max_number):
  for num in range(max_number + 1):
    print(num)


def print_numbers_with_min(min_number,max_number):
  for num in range(min_number,max_number + 1):
    print(num)

def net_price(gross,vat_rate):
  result=gross/(1+vat_rate)
  return result


#default wartosc podatku
def net_price_with_default(gross,vat_rate=0.23):
  result=gross/(1+vat_rate)
  return result


# easy_print()
# print_numbers(5)
# print_numbers_with_min(10,15)

net=net_price(10,0.23)
net2=net_price(100,0.23)
net_def=net_price_with_default(300)
net, net2, net_def
# Out:
# (8.130081300813009, 81.30081300813008, 243.90243902439025)

# %%
#default wartosc podatku
def net_price_with_default(gross,vat_rate=0.23): #correct order
  result=gross/(1+vat_rate)
  return result

#najpierw wpisujemy wartosci funkcji bez defaultu, a nastepnie te defaultowe


def order(item, qty =1,price=30):
  print(f"{qty} x {item}={price}")


order("coffee", qty=10, price=100)
order("water", qty=3,price=2)
# Out:
# 10 x coffee=100
# 3 x water=2

# %%
#paczki

import math

val=9
print(math.sqrt(val))

val2=2.6
print(math.ceil(val2))


val3=2.4
print(math.floor(val3))
# Out:
# 3.0
# 3
# 2

# %%
from math import sqrt,ceil

val=9
print(sqrt(val))

val2=2.6
print(ceil(val2))
# Out:
# 3.0
# 3

# %%
#docstring

def greet(name):
  """
   Return a greeing for the provided name
  """
  return f"Hello {name} "

def add_number(a,b):
  """
  Add two numbers
  """
  return a+b

greet("Kasia")

help(greet)

add_number(4,4)
help(add_number)
# Out:
# Help on function greet in module __main__:
#
# greet(name)
#     Return a greeing for the provided name
#
# Help on function add_number in module __main__:
#
# add_number(a, b)
#     Add two numbers
