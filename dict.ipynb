# %% [markdown]
# <a href="https://colab.research.google.com/github/kkobel001/python_project_learn/blob/main/dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_dict={"car" : 2000, 1:2}
first_dict["car"]

sales= {
    "coffe": 170
    , "tea": 200
    , "waters": 250

}
sales["juice"]=120
sales

sales["juice"] -= 100
sales

sales.keys()
sales.values()
sales.items()
error= "nie ma tego produktu"


sum(sales.values())
# sales["cola"]

if "cola" in sales :
  print("jest cola")
else:
    error

sales.get("cola",error)

sales["cola"] = 0
sales


sales.setdefault("cola",0)
sales
# Out:
# {'coffe': 170, 'tea': 200, 'waters': 250, 'juice': 20, 'cola': 0}
